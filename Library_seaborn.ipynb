# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid') #setting the background

# %%
#tips=sns.load_dataset('tips')
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#sns.relplot(x='total_bill',y='tip',data=tips)
sns.relplot(x='total_bill',y='tip',data=tips) # numerical data polotting- relational plotting

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
#sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',style='size',data=tips)

# %%
from numpy.random import randn

# %%
np.random.seed(100)

# %%
df=pd.DataFrame(dict(time=np.arange(500),value=randn(500).cumsum()))
#cumsum() function is used when we want to compute the cumulative sum of array elements over a given axis

# %%
df.head()
# Out:
#    time     value
# 0     0 -0.210867
# 1     1 -0.887783
# 2     2 -0.752665
# 3     3 -0.916918
# 4     4  0.182803

# %%
sns.relplot(x='time',y='value',data=df,kind='line',sort=True)

# %%
df1=pd.DataFrame(randn(500,2).cumsum(axis=0),columns=['time','value'])

# %%
df1.head()
# Out:
#        time     value
# 0 -0.480433 -1.670012
# 1  1.059721 -0.967376
# 2  0.238075 -1.166872
# 3  2.056489 -0.540331
# 4  2.919441 -0.288600

# %%
sns.relplot(x='time',y='value',data=df1,kind='line',sort=True)

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',ci='sd')
#when you use standard deviation it actualshows actual region

# %%
sns.relplot(x='timepoint',y='signal',estimator=None,data=fmri,kind='line',ci='sd')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,hue='event',kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,hue='event',kind='scatter')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,hue='region',style='event',kind='line')
#fmri.info()

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,hue='region',style='event',kind='line',markers=True,dashes=True)
#fmri.info()

# %%
df2=pd.DataFrame(dict(time=pd.date_range('2019-06-02',periods=500),value=randn(500).cumsum()))

# %%
df2.tail()
# Out:
#           time      value
# 495 2020-10-09   9.406753
# 496 2020-10-10  10.527255
# 497 2020-10-11  10.590717
# 498 2020-10-12   9.259513
# 499 2020-10-13   9.879316

# %%
g=sns.relplot(x='time',y='value',data=df2,kind='line')
g.fig.autofmt_xdate() #it wil help you to display the x axis properly

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',size='size',col='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='size',col_wrap=3,height=3)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri,hue='region',style='event')

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri,hue='region',style='event',markers=True,ci=68,err_style='bars')

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri,hue='region',style='event',markers=True,ci='sd',err_style='bars')

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['petal_length'])

# %% [markdown]
# categorial plotting

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='day',y='total_bill',data=tips,jitter=False)#jitter will help you to display info in single line

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='size',kind='swarm')#kind-swarm help you to display flower type info

# %%
sns.catplot(x='smoker',y='total_bill',data=tips,order=['No','Yes'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='box')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='box',hue='sex')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='box',hue='sex',dodge=False)#dodge will help you to overlap the info

# %%
diamonds=sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color',y='price',kind='boxen',data=diamonds.sort_values('color'))

# %%
sns.catplot(x='total_bill',y='day',hue='sex',kind='violin',data=tips)

# %%
sns.catplot(x='total_bill',y='day',hue='sex',kind='violin',data=tips,split=True)

# %%
g=sns.catplot(x='day',y='total_bill',data=tips,kind='violin',inner=None)
sns.swarmplot(x='day',y='total_bill',data=tips,color='k',size=3,ax=g.ax)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='deck',kind='count',data=titanic,hue='class',palette='ch:0.95')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['Value'])
df.head()
# Out:
#                Value
# 2019-06-07 -0.382516
# 2019-06-08  0.990236
# 2019-06-09  0.514848
# 2019-06-10 -0.577104
# 2019-06-11  0.084970

# %%
df['Value']=df['Value'].cumsum() #n=(n-1)+(n-2)

# %%
df.head()
# Out:
#                Value
# 2019-06-07 -0.382516
# 2019-06-08  0.607720
# 2019-06-09  1.122568
# 2019-06-10  0.545463
# 2019-06-11  0.630433

# %%
df.plot()#index is x axis, values are y axis

# %%
df.plot(figsize=(5,10))

# %%
df.plot(figsize=(10,10))

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ax=iris.plot(figsize=(15,8),title='iris dataset')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.min()
# Out:
# sepal_length       4.3
# sepal_width          2
# petal_length         1
# petal_width        0.1
# species         setosa
# dtype: object

# %%
iris.max()
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
iris.plot(kind='bar')

# %%
df=iris.drop('species',axis=1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0].plot(kind='bar')

# %%
df.plot(kind='bar')

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='bar')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.617943  2.632139  0.125375 -0.351577
# 1  0.769864  2.493931 -0.772283 -0.121634
# 2 -1.865192 -0.121118  0.634923  2.581897
# 3 -0.607192  1.681476 -0.684867  1.128255
# 4 -0.026732  1.261775  0.560953  1.255938

# %%
df.plot.bar()

# %%
df.plot(kind='bar')

# %%
df.plot.barh()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.hist() #x axis-range; y axis -freq of the distribution

# %%
iris.plot(kind='hist',stacked=True,bins=100)

# %%
iris.plot(kind='hist',stacked=False,bins=400)

# %%
iris.plot(kind='hist',stacked=True,bins=100,orientation='horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50)

# %%
df=iris.drop('species',axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.diff().hist(color='r',alpha=0.5,figsize=(10,10))
#alpha =- intensity
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A30E34A9C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A318ECE248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A318F1CEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A318F588C8>]],
#       dtype=object)

# %%
df.plot.scatter(x='sepal_length',y='petal_length')

# %%
 df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=190)

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,C='sepal_width')

# %%
d=df.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
d=df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A31A876648>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31AA13C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31A9F7448>],
#       dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,20),autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A31B65A208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31B67AF48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31B65ADC8>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(8,8),diagonal='kde',color='b')
plt.show()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df,'sepal_width')

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
ts
# Out:
# 2019-06-07    1.028743
# 2019-06-08    0.418356
# 2019-06-09    0.245674
# 2019-06-10    1.339972
# 2019-06-11   -0.125623
#                 ...
# 2022-02-26   -1.092875
# 2022-02-27   -0.163540
# 2022-02-28   -0.572614
# 2022-03-01    0.314501
# 2022-03-02    0.403228
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot(style='r--',label='Series',legend=True)

# %%
df.plot(legend=True,figsize=(10,5),logy=True)

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A31DE45108>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31DE48308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31DE45D48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A31EFF1D48>],
#       dtype=object)

# %%
df.plot(subplots=True,sharex=False,layout=(2,2),figsize=(16,8))
plt.tight_layout()
plt.savefig('subplot.jpg')

# %%
#seaborn
